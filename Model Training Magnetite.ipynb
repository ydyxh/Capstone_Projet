# %% [markdown]
# # Hyperspectral Image Masking Process Using MLP

# %% [markdown]
# The sample file comes from:<br>
# `Sample Dataset > Co-registered > 1M-10-0001 > VNIR-SWIR`<br>
# `Sample Dataset > Minerology > 1M-10-0001 > DDH`<br>
# <font color = 'red'>**VNIR-SWIR** is the very directory contains what we are going to operaterate!</font><br>
# <font color = 'green'>Please put the .hdr file and the corresponding dat file into the LWIR where this notebook located!</font><br>
# <font color = 'blue'>Please put all the mask within DDH folder into the demo folder!</font>

# %% [markdown]
# ## Import basic required packages

# %%
import os
import numpy 
import numpy as np
from spectral import *
from spectral.io import envi
import spectral.io.envi as envi 
import cv2
import glob 

import matplotlib.pyplot as plt
import scipy
from sklearn.decomposition import PCA

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Hyperspectral data (.hdr and .dat)
# **<font color='red'>Please copy and paste the directory of the folder where hdrs are in, make sure that you replace "\\" as "\\\\".</font>**</br>
# Before you go, make sure that the directory is set in where the original file lies in!

# %%
# set directory
os.getcwd()
os.chdir('C:\\Users\\Raymo\\Demo\\VNIR-SWIR (VIEW THIS ONLY)') # target directory

# %% [markdown]
# The code block above only need to execute for one time

# %% [markdown]
# **Then get the list of the corresponding .hdr and .dat**

# %%
lst = os.listdir()
lst
# Out:
# ['DNR_Pasadena_1M-10-0001_10_000_000',
#  'DNR_Pasadena_1M-10-0001_10_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_11_000_000',
#  'DNR_Pasadena_1M-10-0001_11_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_12_000_000',
#  'DNR_Pasadena_1M-10-0001_12_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_13_000_000',
#  'DNR_Pasadena_1M-10-0001_13_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_14_000_000',
#  'DNR_Pasadena_1M-10-0001_14_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_15_000_000',
#  'DNR_Pasadena_1M-10-0001_15_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_16_000_000',
#  'DNR_Pasadena_1M-10-0001_16_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_17_000_000',
#  'DNR_Pasadena_1M-10-0001_17_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_18_000_000',
#  'DNR_Pasadena_1M-10-0001_18_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_19_000_000',
#  'DNR_Pasadena_1M-10-0001_19_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_1_000_000',
#  'DNR_Pasadena_1M-10-0001_1_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_20_000_000',
#  'DNR_Pasadena_1M-10-0001_20_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_2_000_000',
#  'DNR_Pasadena_1M-10-0001_2_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_3_000_000',
#  'DNR_Pasadena_1M-10-0001_3_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_4_000_000',
#  'DNR_Pasadena_1M-10-0001_4_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_5_000_000',
#  'DNR_Pasadena_1M-10-0001_5_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_6_000_000',
#  'DNR_Pasadena_1M-10-0001_6_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_7_000_000',
#  'DNR_Pasadena_1M-10-0001_7_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_8_000_000',
#  'DNR_Pasadena_1M-10-0001_8_000_000.hdr',
#  'DNR_Pasadena_1M-10-0001_9_000_000',
#  'DNR_Pasadena_1M-10-0001_9_000_000.hdr']

# %% [markdown]
# To open the corresponding hdr file, please input the corresponding row you want to read.

# %%
row = input('Please input the number of row indicated in .hdr file. For example, \
DNR_Pasadena_1M-10-0001_3_000_000.hdr means third row, the number MUST between 1 and 20 and is INTEGER!')
if not isinstance(eval(row), int):
    print('Please enter a valid integer! ')
if eval(row) > 20 or eval(row) <= 0:
    print('Please enter an INTEGER BETWEEN 1 and 20')
# Out:
# Please input the number of row indicated in .hdr file. For example, DNR_Pasadena_1M-10-0001_3_000_000.hdr means third row, the number MUST between 1 and 20 and is INTEGER!7

# %%
# hdr data 
img = envi.open(f'DNR_Pasadena_1M-10-0001_{row}_000_000.hdr',f'DNR_Pasadena_1M-10-0001_{row}_000_000')
imshow(img, figsize = (20,8))
# Out:
# ImageView object:
#   Display bands       :  [211, 101, 45]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [539.0, 11642.0]
#     G: [547.0, 9284.0]
#     B: [563.0, 9975.0]

# %% [markdown]
# ## Load And Explore Mask data (DDH)
# In this project, we mainly focus on the mineraology component "Muscovite", and "White-Mica" due to their relative data balance.<br>
# You can expand the DDH folder with other components.<br>
# <font color = 'red'>Please check the number of the row with relatively balanced data before choosing the corresponding hdr file! </font>

# %% [markdown]
# **Get the list of the DDH file, which contains the mask data for the corresponding mineral component.**

# %%
os.chdir('C:\\Users\\Raymo\\Demo\\DDH')
lst = os.listdir()
lst
# print(lst)
# Out:
# ['DNR_Pasadena_1M-10-0001_20_000_000_row_4_1_Rock_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_Any_Mineral_Classified_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_Alunite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_Amphibole_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_Biotite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_Carbonate_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_Chl_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_Epidote_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_chemistry_White-Mica_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_composite_570(R)_790(G)_855(B)_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_composite_Gyp(R)_Prh(O)_Topaz(Y)_Jaro(G)_Alun(B)_Tur(C)_Carb(M)_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_composite_Plag(R)_Fp-Mnst(Y)_KFp-NaK(G)_Fp-MnstMid(C)_KFp-Micro(B)_Fp-Mnst2(M)_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_composite_Pyro(M)_Kaol(R)_Halloy(O)_Dckt(Y)_WM(G)_IllSmec(B)_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_composite_Serp(O)_Chl(R)_Amp(YG)_Grun(YO)_Epi(G)_Zoi(C)_Bt(B)_Talc(M)_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_Crystallinity_White-mica_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_Fasle_Color_LWIR_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_Fasle_Color_MWIR_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_Grain-Size_White-mica_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Alunite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Alunite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Amphibole_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Amphibole_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Biotite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Biotite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Carbonate_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Carbonate_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Chlorite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Chlorite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_chloritoid_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_chloritoid_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Dickite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Dickite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Epidote_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Epidote_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_FeOH_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_FeOH_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Grunerite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Grunerite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Gypsum_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Gypsum_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Halloysite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Halloysite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Hematite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Hematite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Illite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Illite_Mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Jarosite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Jarosite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Kaolinite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Kaolinite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-Amphibole_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-FpMnstMid2_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-FpMnstMid_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-FpMnst_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-FpNaK_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-FpPlagioclase-UNK-LOW_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-FpPlagioclase-UNK_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-Gypsum_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-KFp-Microcline_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-Muscovite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-Quartz_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-Quartz_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-Talc_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-UNK1_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_LWIR-UNK2_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Magnetite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Magnetite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Muscovite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Muscovite_Mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Pen-yellow_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Pen-yellow_Mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_phyllo-LWIR_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Prehnite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Prehnite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Pyrophyllite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Pyrophyllite_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Serpentine_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Serpentine_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Sideite_BR_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Smectite_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Smectite_Mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_SulphideMWIR-EXP_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_SulphideMWIR-EXP_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Talc_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Talc_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Topaz_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Topaz_Mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Tourmaline_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_Tourmaline_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_White-Mica_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_White-Mica_mask_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_MWIR_MASK_TAG_FINAL_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_11000_11500_2_12_40_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_1387_1418_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_1476_1495_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_1541_1570_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_1650_1670_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_1895_1913_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_1980_2015_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2090_2120_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2150_2180_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2180_2220_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2185_2224_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2186_2224_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2239_2262_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2240_2262_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2241_2262_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2305_2325_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2325_2352_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2380_2405_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2383_2400_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2515_2555_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_2516_2555_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_3760_3875_2_8_8_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_3764_3875_2_8_8_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_3800_3840_2_8_8_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_3900_4000_2_8_8_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_5000_5100_2_8_8_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_570_595_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_790_810_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_8200_9000_2_12_40_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_855_880_4_12.0_16_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_9000_9500_2_12_40_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_position_9500_10000_2_12_40_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_VNIR_RGB_Dark_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_VNIR_RGB_DDH.PNG',
#  'DNR_Pasadena_1M-10-0001_20_000_000_row_4_VNIR_RGB_Light_DDH.PNG']

# %% [markdown]
# <font color = 'red'>**Get the name of the mineral component that has corresponding mask**</font>

# %%
res = []
for i in lst:
    if 'Mask' in i or 'mask' in i:
        res.append(i[49:-13])
# print(res)
res
# len(res) 29, which means there are 29 mineral component that has the corresponding mask
# However, there are two components ('LWIR-Quartz', 'SulphideMWIR-EXP') that seems to be not binary mask. According to the EDA.
# Out:
# ['Alunite',
#  'Amphibole',
#  'Biotite',
#  'Carbonate',
#  'Chlorite',
#  'chloritoid',
#  'Dickite',
#  'Epidote',
#  'FeOH',
#  'Grunerite',
#  'Gypsum',
#  'Halloysite',
#  'Hematite',
#  'Illite',
#  'Jarosite',
#  'Kaolinite',
#  'LWIR-Quartz',
#  'Magnetite',
#  'Muscovite',
#  'Pen-yellow',
#  'Prehnite',
#  'Pyrophyllite',
#  'Serpentine',
#  'Smectite',
#  'SulphideMWIR-EXP',
#  'Talc',
#  'Topaz',
#  'Tourmaline',
#  'White-Mica']

# %% [markdown]
# **Please select the component from the list shown above!**

# %%
import matplotlib.image as mpimg
component = input('Please input the component corresponding to the mask, thanks.        ') # White-Mica is shown in this sample
if component not in res: raise ValueError('Please enter a valid mineral component!       ')
a = mpimg.imread(f'DNR_Pasadena_1M-10-0001_20_000_000_row_4_mineral_{component}_Mask_DDH.PNG')
imshow(a, figsize = (70,30), aspect=1)
# Out:
# Please input the component corresponding to the mask, thanks.        Magnetite
# ImageView object:
#   Display bands       :  [0, 1, 2]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 1.0]
#     G: [0.0, 1.0]
#     B: [0.0, 1.0]

# %% [markdown]
# <font color = 'blue'>Please **write down** the number of the row with relatively balanced data. </font><br>
# <font color = 'green'>You may want to input another mineral component if it's almost totally black...</font>

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Preprocessing of hdr file<br>
# <font color = 'red'>First 6 rows and 30 columns doesn't correspond to the valid information on mask!</font>

# %%
arr = np.asarray(img.load())
hdr = arr[6:, 30:]

# %% [markdown]
# Preprocessing of the mask
# <font color='red'>Each mask row (4 rows of sample takes up 156 pixels, <b>the first row of which doesn't contain any info!</b>)</font>

# %%
corr_mask = a[1 + (156 * (int(row) - 1)):156 + (156 * (int(row) - 1)), 0:]
print(corr_mask.shape)
imshow(corr_mask, figsize = (20,8))
# Out:
# (155, 1540, 3)
# ImageView object:
#   Display bands       :  [0, 1, 2]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 1.0]
#     G: [0.0, 1.0]
#     B: [0.0, 1.0]

# %% [markdown]
# <font color = 'red'>You may want to reset the number of the row based on the observation of the entire mask file if the row you have choosen is **almost totally** <font color = 'black'>**black**</font>.</font>

# %% [markdown]
# ## Data preparation for ML

# %% [markdown]
# This method will intercept a rectangular area with a custom size in the picture, extract every pixel array within the area, and split the training set and test set according to a certain ratio.<br>
# <br>
# *Arguments:*<br>
# *hyperspect*: numpy ndarray, hyperspectral array with shape (x,y,z).<br>
# *ddh*: numpy ndarray, ddh mask array with shape (x,y,z), same as the shape of hyperspect.<br>
# *loc*: list like [a,b], where 'a' and 'b' are the coordinates of the top-left point of the rectangle area.<br>
# *length*: int, length of the rectangle area.<br>
# *width*: int, wiidth of the rectangle area.<br>
# *ratio*: ratio of the test set size, 0 < ratio < 1.

# %%
# !pip install keras
# !pip install tensorflow
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
def data_prep (hyperspect, ddh, loc, length, width, ratio):
    # intialize using the starting location
    hyp = hyperspect[loc[0],loc[1]]
    mask = np.array([1])
    
    # check if outOfBound
    if loc[0]+width > hyperspect.shape[0]-1 or loc[1]+length > hyperspect.shape[1]-1 :
        raise Exception("Warning: length or width too large..")
    
    # add all pixel arrays within area
    for i in range(loc[0], loc[0]+width):
        for j in range(loc[1], loc[1]+length):
            hyp = np.vstack((hyp, hyperspect[i,j]))
            
            # For ddh mask, we extract it categorically.
            # For pixel channel = 112 or 255, we append value 1.
            # For pixel channel = 0, we append value 0
            if ddh[i,j,1] > 0: # note that the 3rd dimension of the mask contains 0 and 1 ONLY!
                mask = np.concatenate((mask,[1]))
            else:
                mask = np.concatenate((mask,[0]))
            
    
    # delete the first element that is repeated
    hyp = hyp[1:]
    mask = mask[1:]
    
    X_train, X_test, y_train, y_test = train_test_split(hyp, mask, test_size=ratio)
    
    # change the y set into categorical set 
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)
    
    return hyp, mask, X_train, X_test, y_train, y_test

# %%
start_point = input('Enter the start point (upper left point) of the pixel you want to take, eg: [2, 2]     ')
length = input('Enter the HORIZONTAL length of the pixel you want to take.     ')
width = input('Enter the VERTICAL width of the pixel you want to take.     ')
# Out:
# Enter the start point (upper left point) of the pixel you want to take, eg: [2, 2]     [50,400]
# Enter the HORIZONTAL length of the pixel you want to take.     100
# Enter the VERTICAL width of the pixel you want to take.     80

# %%
loc = eval(start_point)
h, m, X_train, X_test, y_train, y_test = data_prep(hdr, corr_mask, loc, eval(length), eval(width), 0.05)

# %%
print("Hypspec: ", str(h.shape))
print("DDH:     ", str(m.shape))
print("X_train: ", str(X_train.shape))
print("y_train: ", str(y_train.shape))
print("X_test:  ", str(X_test.shape))
print("y_test:  ", str(y_test.shape))
# Out:
# Hypspec:  (8000, 1223)
# DDH:      (8000,)
# X_train:  (7600, 1223)
# y_train:  (7600, 2)
# X_test:   (400, 1223)
# y_test:   (400, 2)

# %%
y_test[:,0].mean()
# Out:
# 0.7275

# %% [markdown]
# If the output above is **> 0.75** or **<0.25**, it means the sample frame you have selected is very inbalanced!!

# %% [markdown]
# ## Preprocessing of the Train and Test Array
# Since we have extract the array information for each pixel (an array contains 1223 numbers), to extract its abnomality (fluctration information), we use the next value - current value as its equivalant of the deriviation.

# %%
def x_prep(x_train, x_test) -> object:
    # x_train
    for i in x_train:
        for j in range(len(i) - 1):
            i[j] = int(i[j + 1]) - int(i[j])  # next val - curr val -- deriviation
    
    # x_test
    for k in x_test:
        for l in range(len(k) - 1):
            k[l] = int(k[l + 1]) - int(k[l])
            
    return x_train[:, :x_train.shape[1] - 1], x_test[:, :x_test.shape[1] - 1]

# %% [markdown]
# **You can execute the block above n time to gain an n order derivation of the array**,<br>
# This is done to extract the feature within the array within each pixel.

# %%
n_order_derivation = int(input('Please input the n of the order of the deriviation, usually 1 or 2.    '))
for i in range(n_order_derivation):
    X_train, X_test = x_prep(X_train, X_test)
# Out:
# Please input the n of the order of the deriviation, usually 1 or 2.    1

# %% [markdown]
# ## Machine Learning Model -- MLP

# %%
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# %% [markdown]
# **Input shape = (1223 - n,)**, n stands for the # of the deriviation order<br>
# <font color='red'>In this case, n = 1, therefore, input shape is 1223 - 1 = 1222.</font>

# %%
model = Sequential([
            Dense(1223 - n_order_derivation, activation='softplus', input_shape=(1223 - n_order_derivation,)),
            # Dense(2048, activation = 'gelu'),
            Dense(800, activation='tanh'),
            Dense(270, activation='elu'),
            Dense(95, activation='tanh'),
            Dense(2, activation='softmax'),
        ])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1222)              1494506
#
#  dense_1 (Dense)             (None, 800)               978400
#
#  dense_2 (Dense)             (None, 270)               216270
#
#  dense_3 (Dense)             (None, 95)                25745
#
#  dense_4 (Dense)             (None, 2)                 192
#
# =================================================================
# Total params: 2715113 (10.36 MB)
# Trainable params: 2715113 (10.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Training.
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 760/760 [==============================] - 12s 15ms/step - loss: 0.3267 - accuracy: 0.8628 - val_loss: 0.2834 - val_accuracy: 0.8775
# Epoch 2/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.2202 - accuracy: 0.9182 - val_loss: 0.2095 - val_accuracy: 0.9300
# Epoch 3/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.1917 - accuracy: 0.9274 - val_loss: 0.1961 - val_accuracy: 0.9300
# Epoch 4/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.1715 - accuracy: 0.9418 - val_loss: 0.2244 - val_accuracy: 0.9300
# Epoch 5/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.1479 - accuracy: 0.9493 - val_loss: 0.2396 - val_accuracy: 0.9025
# Epoch 6/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.1267 - accuracy: 0.9622 - val_loss: 0.2554 - val_accuracy: 0.9200
# Epoch 7/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.1079 - accuracy: 0.9707 - val_loss: 0.2220 - val_accuracy: 0.9400
# Epoch 8/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.0914 - accuracy: 0.9778 - val_loss: 0.3045 - val_accuracy: 0.9175
# Epoch 9/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.0816 - accuracy: 0.9805 - val_loss: 0.3209 - val_accuracy: 0.9275
# Epoch 10/10
# 760/760 [==============================] - 11s 15ms/step - loss: 0.0780 - accuracy: 0.9811 - val_loss: 0.2376 - val_accuracy: 0.9325

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Plot the training accuracy
plt.clf()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = []
for i in range(10):
    epochs.append(i+1)

plt.plot(epochs, acc, 'bo', label='Train Accuracy')
plt.plot(epochs, val_acc, 'b', label='Test accuracy')
plt.title('Training Results for MLP in Magnetite')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
y_test
model.predict(X_test)
# Out:
# 13/13 [==============================] - 0s 4ms/step
# array([[0.9957684 , 0.00423154],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423155],
#        [0.5407201 , 0.4592799 ],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423163],
#        [0.99576855, 0.00423152],
#        [0.9957682 , 0.00423181],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.00423165],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.99576795, 0.00423201],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423165],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.85836685, 0.14163312],
#        [0.9957684 , 0.00423158],
#        [0.9957683 , 0.00423167],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423155],
#        [0.04973472, 0.9502652 ],
#        [0.9957683 , 0.00423176],
#        [0.9957682 , 0.00423179],
#        [0.99576783, 0.00423216],
#        [0.04973471, 0.95026535],
#        [0.9769539 , 0.02304613],
#        [0.9957658 , 0.0042342 ],
#        [0.04973473, 0.9502652 ],
#        [0.9957684 , 0.00423155],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423155],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.0042317 ],
#        [0.96830785, 0.03169217],
#        [0.99576855, 0.00423152],
#        [0.04973471, 0.95026535],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423162],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973473, 0.9502652 ],
#        [0.9957684 , 0.00423153],
#        [0.9957684 , 0.00423155],
#        [0.0497348 , 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973471, 0.95026535],
#        [0.04973473, 0.9502652 ],
#        [0.9957684 , 0.00423158],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423158],
#        [0.3357353 , 0.6642647 ],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423158],
#        [0.9957684 , 0.00423154],
#        [0.99576783, 0.00423219],
#        [0.99533504, 0.00466498],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.00423175],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423153],
#        [0.9957683 , 0.00423174],
#        [0.9957684 , 0.00423155],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423153],
#        [0.0544724 , 0.94552755],
#        [0.99576855, 0.00423153],
#        [0.04973471, 0.95026535],
#        [0.04973477, 0.9502652 ],
#        [0.04973472, 0.9502652 ],
#        [0.9957683 , 0.0042317 ],
#        [0.9957684 , 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.04973471, 0.95026535],
#        [0.99570024, 0.00429978],
#        [0.29901734, 0.70098263],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423158],
#        [0.9957684 , 0.00423155],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9551632 , 0.04483677],
#        [0.9957684 , 0.00423153],
#        [0.25556466, 0.74443537],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423153],
#        [0.9957681 , 0.00423197],
#        [0.9957683 , 0.00423175],
#        [0.99576855, 0.00423152],
#        [0.99314636, 0.00685357],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423152],
#        [0.9957681 , 0.00423194],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423153],
#        [0.04973473, 0.9502652 ],
#        [0.10194831, 0.8980517 ],
#        [0.994304  , 0.00569594],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423153],
#        [0.9957684 , 0.00423156],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973483, 0.9502651 ],
#        [0.9957682 , 0.00423184],
#        [0.9957684 , 0.00423155],
#        [0.9957684 , 0.00423164],
#        [0.99576855, 0.00423153],
#        [0.9957681 , 0.00423195],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423154],
#        [0.04973869, 0.95026135],
#        [0.9263352 , 0.07366477],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.0497347 , 0.95026535],
#        [0.9957684 , 0.00423155],
#        [0.9957682 , 0.00423189],
#        [0.9957684 , 0.00423155],
#        [0.04973475, 0.9502652 ],
#        [0.04977645, 0.95022357],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423158],
#        [0.04973471, 0.95026535],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423161],
#        [0.9957684 , 0.00423154],
#        [0.04973472, 0.9502652 ],
#        [0.04973471, 0.95026535],
#        [0.05013343, 0.9498666 ],
#        [0.9957683 , 0.00423166],
#        [0.99576855, 0.00423152],
#        [0.04973535, 0.9502647 ],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423162],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423164],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.0497348 , 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.04973772, 0.9502623 ],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423163],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423155],
#        [0.99576855, 0.00423153],
#        [0.9957682 , 0.0042318 ],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423158],
#        [0.9957684 , 0.00423158],
#        [0.9957684 , 0.00423157],
#        [0.04973473, 0.9502652 ],
#        [0.9957684 , 0.00423155],
#        [0.9957683 , 0.00423171],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423164],
#        [0.9957684 , 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423159],
#        [0.34643075, 0.6535692 ],
#        [0.887868  , 0.11213202],
#        [0.99576855, 0.00423152],
#        [0.88937855, 0.11062142],
#        [0.9957684 , 0.00423154],
#        [0.04973471, 0.95026535],
#        [0.04973471, 0.95026535],
#        [0.04973472, 0.9502652 ],
#        [0.04973471, 0.95026535],
#        [0.04973471, 0.95026535],
#        [0.99576855, 0.00423152],
#        [0.04982746, 0.95017254],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423153],
#        [0.9957684 , 0.00423158],
#        [0.9957684 , 0.00423154],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423158],
#        [0.36606565, 0.6339343 ],
#        [0.99576855, 0.00423153],
#        [0.04973479, 0.9502652 ],
#        [0.9957684 , 0.00423156],
#        [0.04973471, 0.95026535],
#        [0.7478841 , 0.25211594],
#        [0.99576855, 0.00423153],
#        [0.04973491, 0.9502651 ],
#        [0.07620297, 0.923797  ],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9919858 , 0.00801416],
#        [0.9957684 , 0.00423156],
#        [0.9957683 , 0.00423168],
#        [0.9957684 , 0.00423155],
#        [0.9957684 , 0.00423156],
#        [0.99576855, 0.00423153],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423157],
#        [0.9957684 , 0.00423153],
#        [0.9957684 , 0.00423155],
#        [0.19792035, 0.8020797 ],
#        [0.9957684 , 0.00423164],
#        [0.99576855, 0.00423152],
#        [0.04973471, 0.95026535],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.00423171],
#        [0.04973472, 0.9502652 ],
#        [0.04973473, 0.9502652 ],
#        [0.9957684 , 0.00423164],
#        [0.9957683 , 0.00423165],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423153],
#        [0.04973473, 0.9502652 ],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423156],
#        [0.04973549, 0.9502645 ],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.00423169],
#        [0.04974271, 0.9502573 ],
#        [0.0497347 , 0.95026535],
#        [0.04973471, 0.95026535],
#        [0.9957684 , 0.00423156],
#        [0.9957684 , 0.00423154],
#        [0.9957684 , 0.00423153],
#        [0.9925281 , 0.00747191],
#        [0.05186294, 0.9481371 ],
#        [0.04973471, 0.95026535],
#        [0.9957676 , 0.00423238],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.04973481, 0.9502652 ],
#        [0.04973649, 0.9502635 ],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423156],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973473, 0.9502652 ],
#        [0.9957683 , 0.00423168],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423153],
#        [0.05336081, 0.9466392 ],
#        [0.9957684 , 0.00423164],
#        [0.04973483, 0.9502651 ],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423153],
#        [0.04973471, 0.95026535],
#        [0.04973472, 0.9502652 ],
#        [0.99196553, 0.00803443],
#        [0.9957684 , 0.0042316 ],
#        [0.9957684 , 0.00423164],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957682 , 0.00423182],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423159],
#        [0.9957684 , 0.00423161],
#        [0.9957682 , 0.00423181],
#        [0.9957684 , 0.00423158],
#        [0.9957684 , 0.00423158],
#        [0.99575895, 0.004241  ],
#        [0.9957682 , 0.00423178],
#        [0.04973471, 0.95026535],
#        [0.04973473, 0.9502652 ],
#        [0.9957684 , 0.00423154],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.0042317 ],
#        [0.9957684 , 0.00423156],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423157],
#        [0.99576855, 0.00423153],
#        [0.04973471, 0.95026535],
#        [0.99515235, 0.00484759],
#        [0.9957684 , 0.00423155],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423157],
#        [0.9957684 , 0.00423155],
#        [0.04973472, 0.9502652 ],
#        [0.04973471, 0.95026535],
#        [0.04973471, 0.95026535],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423154],
#        [0.9957683 , 0.00423176],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423153],
#        [0.99576855, 0.00423152],
#        [0.04973474, 0.9502652 ],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973475, 0.9502652 ],
#        [0.9957683 , 0.00423168],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.00423164],
#        [0.04973472, 0.9502652 ],
#        [0.04973471, 0.95026535],
#        [0.23756453, 0.7624355 ],
#        [0.05148551, 0.94851446],
#        [0.04973472, 0.9502652 ],
#        [0.04973472, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423152],
#        [0.04973472, 0.9502652 ],
#        [0.98096347, 0.01903653],
#        [0.9957677 , 0.0042323 ],
#        [0.99576855, 0.00423152],
#        [0.9957683 , 0.00423166],
#        [0.0497347 , 0.95026535],
#        [0.99576855, 0.00423153],
#        [0.99576783, 0.00423215],
#        [0.9957684 , 0.00423154],
#        [0.04973473, 0.9502652 ],
#        [0.9957671 , 0.00423292],
#        [0.9530337 , 0.04696635],
#        [0.99576855, 0.00423152],
#        [0.99576783, 0.00423216],
#        [0.99576855, 0.00423152],
#        [0.9957684 , 0.0042316 ],
#        [0.04973473, 0.9502652 ],
#        [0.9319436 , 0.0680564 ],
#        [0.9957684 , 0.00423157],
#        [0.9957684 , 0.00423164],
#        [0.995745  , 0.00425504],
#        [0.99576855, 0.00423153],
#        [0.9957682 , 0.00423184],
#        [0.99576855, 0.00423152],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.04973471, 0.95026535],
#        [0.04973765, 0.9502623 ],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423159],
#        [0.9957684 , 0.00423153],
#        [0.04973472, 0.9502652 ],
#        [0.9957684 , 0.00423157],
#        [0.9957682 , 0.00423184],
#        [0.04973477, 0.9502652 ],
#        [0.99576855, 0.00423153],
#        [0.9957684 , 0.00423153],
#        [0.8574773 , 0.14252263],
#        [0.04973473, 0.9502652 ],
#        [0.99576855, 0.00423152],
#        [0.99576855, 0.00423153]], dtype=float32)

# %% [markdown]
# ### Conduct External Test

# %% [markdown]
# Choose another different hdr file

# %%
# set directory
os.chdir('C:\\Users\\Raymo\\Demo\\VNIR-SWIR (VIEW THIS ONLY)') # target directory
external_row = input('Please input the number of row indicated in .hdr file. For example, \
DNR_Pasadena_1M-10-0001_3_000_000.hdr means third row, the number MUST between 1 and 20 and is INTEGER!')
if not isinstance(eval(external_row), int):
    raise ValueError('Please enter a valid integer! ')
if eval(external_row) > 20 or eval(external_row) <= 0:
    raise ValueError('Please enter an INTEGER BETWEEN 1 and 20')
if eval(external_row) == eval(row):
    raise ValueError("You had better select a different hdr file")
# Out:
# Please input the number of row indicated in .hdr file. For example, DNR_Pasadena_1M-10-0001_3_000_000.hdr means third row, the number MUST between 1 and 20 and is INTEGER!4

# %%
# read and process selected "external" hdr file
external_img = envi.open(f'DNR_Pasadena_1M-10-0001_{external_row}_000_000.hdr',f'DNR_Pasadena_1M-10-0001_{external_row}_000_000')
external_arr = np.asarray(external_img.load())
external_hdr = arr[6:, 30:]

# %%
external_corr_mask = a[1 + (156 * (int(external_row) - 1)):156 + (156 * (int(external_row) - 1)), 0:]
print(external_corr_mask.shape)
imshow(external_corr_mask, figsize = (20,8))
# Out:
# (155, 1540, 3)
# ImageView object:
#   Display bands       :  [0, 1, 2]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [0.0, 1.0]
#     G: [0.0, 1.0]
#     B: [0.0, 1.0]

# %% [markdown]
# <font color='red'>Please choose the corresponding test sample frame based on the mask image shown above, ensure that **the data is BALANCED**</font><br>
# To save time, **don't choose too large external test sample frame!!**

# %%
start_point = input('Enter the start point (upper left point) of the pixel you want to take, eg: [2, 2]     ')
length = input('Enter the HORIZONTAL length of the pixel you want to take.     ')
width = input('Enter the VERTICAL width of the pixel you want to take.     ')
# Out:
# Enter the start point (upper left point) of the pixel you want to take, eg: [2, 2]     [45,95]
# Enter the HORIZONTAL length of the pixel you want to take.     100
# Enter the VERTICAL width of the pixel you want to take.     40

# %%
def external_data_prep (hyperspect, ddh, loc, length, width):
    # intialize using the starting location
    hyp = hyperspect[loc[0],loc[1]]
    mask = np.array([1])
    
    # check if outOfBound
    if loc[0]+width > hyperspect.shape[0]-1 or loc[1]+length > hyperspect.shape[1]-1 :
        raise Exception("Warning: length or width too large..")
    
    # add all pixel arrays within area
    for i in range(loc[0], loc[0]+width):
        for j in range(loc[1], loc[1]+length):
            hyp = np.vstack((hyp, hyperspect[i,j]))
            
            # For ddh mask, we extract it categorically.
            # For pixel channel = 112 or 255, we append value 1.
            # For pixel channel = 0, we append value 0
            if ddh[i,j,1] > 0: # note that the 3rd dimension of the mask contains 0 and 1 ONLY!
                mask = np.concatenate((mask,[1]))
            else:
                mask = np.concatenate((mask,[0]))
            
    
    # delete the first element that is repeated
    hyp = hyp[1:]
    mask = mask[1:]
    
    X_external_test, y_external_test = hyp, mask

    
    # change the y set into categorical set 
    y_external_test = to_categorical(y_external_test)
    
    return hyp, mask, X_external_test, y_external_test




loc = eval(start_point)
h, m, X_external_test, y_external_test = external_data_prep(external_hdr, external_corr_mask, loc, eval(length), eval(width))

# %%
def x_external_prep(X_external_test) -> object:
    for i in X_external_test:
        for j in range(len(i) - 1):
            i[j] = int(i[j + 1]) - int(i[j])  # next val - curr val -- deriviation
    return X_external_test[:, :X_external_test.shape[1] - 1]
X_external_test = x_external_prep(X_external_test)

# %% [markdown]
# Check the balance of the data, should be <=0.75 and >=0.25

# %%
y_external_test[:,1].mean()
# Out:
# 0.25675

# %% [markdown]
# **Conduct External Test**

# %%
score = model.evaluate(X_external_test, y_external_test, verbose = 0)
print(f'Test loss: {score[0]}; test accurracy: {score[1]}')
# Out:
# Test loss: 1.4046778678894043; test accurracy: 0.7419999837875366
